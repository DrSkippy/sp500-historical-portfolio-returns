# %%
import matplotlib
from matplotlib import pyplot as plt
import seaborn as sns
sns.set_theme()
# %matplotlib inline

# %%
from returns.data import *
from returns.analysis import *

# %%
files = ! ls ../out_data/summary*
for i, f in enumerate(files):
    print(f"{i} : {f}")
# Out:
# 0 : ../out_data/summary_Buy_Hold_2026-03-14_1834.csv
# 1 : ../out_data/summary_Fractional_Kelly_0.1_180_2026-03-14_1834.csv
# 2 : ../out_data/summary_Fractional_Kelly_0.15_180_2026-03-14_1834.csv
# 3 : ../out_data/summary_Fractional_Kelly_0.15_90_2026-03-14_1834.csv
# 4 : ../out_data/summary_Fractional_Kelly_0.1_90_2026-03-14_1834.csv
# 5 : ../out_data/summary_Fractional_Kelly_0.2_180_2026-03-14_1834.csv
# 6 : ../out_data/summary_Fractional_Kelly_0.25_180_2026-03-14_1834.csv
# 7 : ../out_data/summary_Fractional_Kelly_0.25_90_2026-03-14_1834.csv
# 8 : ../out_data/summary_Fractional_Kelly_0.2_90_2026-03-14_1834.csv
# 9 : ../out_data/summary_Insurance_0.05_0.09_90_2026-03-14_1834.csv
# 10 : ../out_data/summary_Insurance_0.05_0.12_90_2026-03-14_1834.csv
# 11 : ../out_data/summary_Insurance_0.05_0.18_90_2026-03-14_1834.csv
# 12 : ../out_data/summary_Insurance_0.1_0.09_90_2026-03-14_1834.csv
# 13 : ../out_data/summary_Insurance_0.1_0.12_90_2026-03-14_1834.csv
# 14 : ../out_data/summary_Insurance_0.1_0.18_90_2026-03-14_1834.csv

# %%
d, h = read_summary_data(files[0])
plot_histograms(h)

# %%
show_metrics(d.iloc[10].to_list())
# Out:
# ### AGGREGATE RETURNS ### Buy_Hold ###
# Sample Size              = 7134
# Time span                =  11.0 years
# Mean Returns             = 134.19%
# Avg Yearly Return        = 7.13%
# Median Returns           = 120.26%
# Median Yearly Returns    = 7.44%
# StdDev of Returns        = 102.36%
# StdDev of Yearly Returns = 4.54%
# Losing start days        = 6.67%
# Mode of Returns          = -0.25%
# Mode of Yearly Returns   = 11.18%

# %%
drf = get_model_comparison_data(files)
#drf = drf.sort_values("model_name")
plot_period_comparison_data(drf)
